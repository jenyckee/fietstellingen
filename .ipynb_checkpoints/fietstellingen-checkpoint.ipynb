# %%
from glob import glob
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# !pip install pandas numpy matplotlib
# Out:
# Requirement already satisfied: pandas in /Users/jenyckee/opt/miniconda3/lib/python3.7/site-packages (1.2.3)
# Requirement already satisfied: numpy in /Users/jenyckee/opt/miniconda3/lib/python3.7/site-packages (1.20.2)
# Requirement already satisfied: matplotlib in /Users/jenyckee/opt/miniconda3/lib/python3.7/site-packages (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/jenyckee/opt/miniconda3/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/jenyckee/opt/miniconda3/lib/python3.7/site-packages (from pandas) (2020.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/jenyckee/opt/miniconda3/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jenyckee/opt/miniconda3/lib/python3.7/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jenyckee/opt/miniconda3/lib/python3.7/site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jenyckee/opt/miniconda3/lib/python3.7/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: six>=1.5 in /Users/jenyckee/opt/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.14.0)

# %%
filenames = glob('data*.csv')

# %%
dataframes = [pd.read_csv(f, 
                          header=None, 
                          names=["site", "direction", "type", "from", "to", "count"],
                          parse_dates=['from', 'to'],
                          index_col=['from']
                         ) for f in filenames]

# %%
df = pd.concat(dataframes)

# %%
df[(df.direction == 'IN')]
# Out:
#                      site direction      type                  to  count
# from
# 2019-08-01 00:00:00     1        IN  FIETSERS 2019-08-01 00:15:00    0.0
# 2019-08-01 00:15:00     1        IN  FIETSERS 2019-08-01 00:30:00    0.0
# 2019-08-01 00:30:00     1        IN  FIETSERS 2019-08-01 00:45:00    0.0
# 2019-08-01 00:45:00     1        IN  FIETSERS 2019-08-01 01:00:00    0.0
# 2019-08-01 01:00:00     1        IN  FIETSERS 2019-08-01 01:15:00    1.0
# ...                   ...       ...       ...                 ...    ...
# 2021-02-28 22:45:00    25        IN  FIETSERS 2021-02-28 23:00:00    0.0
# 2021-02-28 23:00:00    25        IN  FIETSERS 2021-02-28 23:15:00    0.0
# 2021-02-28 23:15:00    25        IN  FIETSERS 2021-02-28 23:30:00    0.0
# 2021-02-28 23:30:00    25        IN  FIETSERS 2021-02-28 23:45:00    0.0
# 2021-02-28 23:45:00    25        IN  FIETSERS 2021-03-01 00:00:00    2.0
#
# [1515586 rows x 5 columns]

# %%
grouped = df.groupby('site').resample('1d').agg({'count': np.sum})

# %%
grouped.unstack('site').plot(figsize=(50,30))
# Out:
# <AxesSubplot:xlabel='from'>
